# %% [markdown]
# Arquivo de configuração do bot, o src_type pode ser 'animation', 'video' ou 'photo' para permitir mais tipos, editar o método de dialog.message.SendMessage

# %%
import json

# a Python object (dict):
x = {"welcome": [{"text": ("🙂 Bem vindo(a) ao *IQA IMDB (bot)*!\n\n"
                "Este bot tem como objetivo responder perguntas no "
                "domínio do IMBD.\n\n"
                "    📌 Dicas e instruções de uso podem ser acessadas "
                "através do comando /help.\n"
                "    📌 Informações sobre o bot estão disponíveis no "
                "comando /about.\n\n"
                "*Aperte em um dos botões abaixo para ver mais informações.*"
                ),
                "src": "",
                "src_type": ""
                },
                {"text": ("❔ *Como utilizar este bot:* \n\n"
                "   1️⃣  Use o comando `/start_iqa` para iniciar a conversa.\n️"
                "          💡 Você poderá usar esse comando novamente após "
                "finalizar uma conversa com o comando `/done`.\n"
                "   2️⃣  _Envie a pergunta desejada no campo de enviar mensagem._\n"
                "          💡 Você poderá ver alguns exemplos de perguntas "
                "ao utilizar o comando `/examples`.\n"
                "   3️⃣  Para finalizar a conversa utilize o comando `/done`.\n\n"
                "*Para ver mais dicas e instruções de uso, utilize o comando /help.*"
                ),
                "src": "",
                "src_type": ""
                }],
      "start_iqa":{
        "private": {"text": ("Olá, por favor, envie a pergunta desejada para "
                    "que eu possa responder. Para finalizar a nossa conversa use o comando "
                    "/done.")},
        "public": {"text": "A conversa é iniciada apenas em *chat privado*❕.",
                    "button_text": "🟢 Iniciar"
                  }
    },
    "examples":{
        "text": "Você pode clicar em um dos exemplos abaixo para enviar uma pergunta ao Bot.",
        "examples": [
            "Qual é o gênero do filme Goodfellas?",
            "Qual é a data de nascimento da ator Leonardo DiCaprio?",
            "Liste-me os filmes do gênero aventura.",
            "Quais são filmes do diretor Quentin Tarantino?",
            "Qual foi o orçamento do filme Goodfellas?",
            "O ator Leonardo DiCaprio ganhou quais prêmios?"
            ]
    },
    "loading": {
        "text": "⏳ _Consultando a base, aguarde, por favor..._"
    },
    "help":[{
        "text": ("Seja bem-vindo(a) ao menu de *Ajuda*\n\n"
                 "A conversa é iniciada usando o comando `/start_iqa` e finalizada com o "
                 "comando `/done`. Você pode repetir esse processo várias vezes, caso haja algum erro, você pode me contatar via @JessicaContatoBot.\n\n"
                " ‼️ É necessário especificar o tipo do que se é perguntado, a seguir mostramos exemplos "
                "onde o tipo está destacado em negrito.\n\n"
                "          - Quais os filmes do *gênero* terror?\n"
                "          - Quais os filmes com o *ator* Leonardo DiCaprio?\n"
                "          - Quais os filmes da *empresa* Paramount?\n"
                "          - Quem dirigiu o *filme* Goodfellas?\n\n"
                "Você pode utilizar os botões de navegação abaixo para ver mais informações."
                 ),
        "src": "AgACAgEAAxkBAAMdXwdLQbg32ytt5Bw1wIDWt-TcscoAAm6pMRvEXKhGqEFj1QtkrMEU5GsGAAQBAAMCAAN4AAOqNAQAARoE",
        "src_type": "photo"
        },
        {
        "text": ("Para cada pergunta que você realiza é esperada uma mensagem, se tudo ocorrer bem, as mensagens informarão "
                 " a você que nenhum resultado foi encontrado ou a resposta.\n\n"
                 "`Obs: Por causa do dataset o título de filmes e séries devem ser informadas na sua língua original. Como exemplo podemos mencionar a série 'Um Maluco no Pedaço' a qual deve ser referenciada como 'The Fresh Prince of Bel-air'.`"), 
        "src": "AgACAgEAAxkBAAMeXwdLQdUlp1zJB-674qNlYciF0zsAAm-pMRvEXKhGofTQTkS_ehbD2W4GAAQBAAMCAANtAANFaQIAARoE",
        "src_type": "photo"
        },
        {
        "text": ("Além da resposta, uma lista de *sugestões relacionadas a pergunta* irá aparecer. "
                 "Você pode selecionar uma dessas sugestões ou apenas ignorar e fazer outra pergunta. "
                 "A lista de sugestões é exibida abaixo do campo de mensagem."),
        "src": "AgACAgEAAxkBAAMfXwdLQQKgI6Msvt3bf8eRkQUoDhcAAnCpMRvEXKhGDZ7ciWBiavJk22sGAAQBAAMCAANtAAPgLAQAARoE",
        "src_type": "photo"
        }
    ],
    "about":[{
        "text": ("O *IQA IMDb (bot)* foi desenvolvido em python utilizando a "
                 "biblioteca [python-telegram-bot](https://python-telegram-bot.org/). "
                 "Utilizamos a ontologia [IMDB Movie Ontology](https://github.com/ontop/ontop/wiki/Example_MovieOntology) como caso de uso."
                ),
        "src": "",
        "src_type": ""
    }],
    "done":{
        "redirect": {"text": ("Conversa finalizada, até a próxima 👋. Você pode iniciar outra "
                    "conversa utilizando o comando `/start_iqa`. Para avaliar este bot [clique aqui](http://t.me/avaliacaobot?start={0}).")},
        "default": {"text": "Você deve enviar pelo menos uma mensagem antes de finalizar a conversa."}
    },
    "eval_options": [["Certo ✔️", 1], ["Errado ❌", 0]]
}
    
with open('template.json', 'w') as outfile:
     json.dump(x, outfile, indent=4)
